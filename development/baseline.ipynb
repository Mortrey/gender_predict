# %% [markdown]
# # Импорты

# %%
import pandas as pd
import json
from collections import Counter

# %% [markdown]
# # Обработка тренировочного датасета

# %%
# зададим директорию
file_path_cut = 'train.json'

# %%
# загружаем наш тренировочный набор данных
df_train = pd.read_json(file_path_cut)

# %%
# смотрим сверху - ужас наши юзеры в колонках мы так не привыкли
df_train.head()
# Out:
#                                                      user_1  \
# target                                               female
# features  {'orders': [{'site-id': 1, 'orders': [{'create...
#
#                                                      user_2  \
# target                                               female
# features  {'visits': [{'site-id': 3, 'first-seen': 16962...
#
#                                                      user_3  \
# target                                                 male
# features  {'orders': [{'site-id': 21, 'orders': [{'creat...
#
#                                                      user_4  \
# target                                                 male
# features  {'orders': [{'site-id': 2, 'orders': [{'create...
#
#                                                      user_5  \
# target                                               female
# features  {'orders': [{'site-id': 39, 'orders': [{'creat...
#
#                                                      user_6  \
# target                                               female
# features  {'orders': [{'site-id': 123, 'orders': [{'crea...
#
#                                                      user_7  \
# target                                               female
# features  {'visits': [{'site-id': 225, 'first-seen': 169...
#
#                                                      user_8  \
# target                                               female
# features  {'orders': [{'site-id': 196, 'orders': [{'crea...
#
#                                                      user_9  \
# target                                               female
# features  {'orders': [{'site-id': 307, 'orders': [{'crea...
#
#                                                     user_10  ...  \
# target                                                 male  ...
# features  {'orders': [{'site-id': 49, 'orders': [{'creat...  ...
#
#                                                 user_127746  \
# target                                                 male
# features  {'orders': [{'site-id': 173, 'orders': [{'crea...
#
#                                                 user_127747  \
# target                                               female
# features  {'visits': [{'site-id': 3, 'first-seen': 16897...
#
#                                                 user_127748  \
# target                                                 male
# features  {'orders': [{'site-id': 348, 'orders': [{'crea...
#
#                                                 user_127749  \
# target                                               female
# features  {'orders': [{'site-id': 39, 'orders': [{'creat...
#
#                                                 user_127750  \
# target                                                 male
# features  {'orders': [{'site-id': 41, 'orders': [{'creat...
#
#                                                 user_127751  \
# target                                                 male
# features  {'orders': [{'site-id': 307, 'orders': [{'crea...
#
#                                                 user_127752  \
# target                                                 male
# features  {'orders': [{'site-id': 147, 'orders': [{'crea...
#
#                                                 user_127753  \
# target                                               female
# features  {'orders': [{'site-id': 20, 'orders': [{'creat...
#
#                                                 user_127754  \
# target                                               female
# features  {'orders': [{'site-id': 407, 'orders': [{'crea...
#
#                                                 user_127755
# target                                               female
# features  {'orders': [{'site-id': 726, 'orders': [{'crea...
#
# [2 rows x 127755 columns]

# %%
# транспонируем датасет что бы он принял человеческий вид
df_transposed = df_train.T

# зададим имена колонок (важно когда будем работать с тестовым набором то колонки таргет у нас не будет)
df_transposed.reset_index(inplace=True)
df_transposed.rename(columns={'index': 'user_id', 0: 'target', 1: 'features'}, inplace=True)

# Посмотрим что получилось
df_transposed.head()
# Out:
#   user_id  target                                           features
# 0  user_1  female  {'orders': [{'site-id': 1, 'orders': [{'create...
# 1  user_2  female  {'visits': [{'site-id': 3, 'first-seen': 16962...
# 2  user_3    male  {'orders': [{'site-id': 21, 'orders': [{'creat...
# 3  user_4    male  {'orders': [{'site-id': 2, 'orders': [{'create...
# 4  user_5  female  {'orders': [{'site-id': 39, 'orders': [{'creat...

# %% [markdown]
# # Создадим правило определения пола - Пол определяется сайтами и покупками человека

# %%
# найдем все унникальные ключи внути ключа features
unique_keys = set()
for features in df_transposed['features']:
    unique_keys.update(features.keys())

# создадим из них новые колонки извлекая данные из 'features'
for key in unique_keys:
    df_transposed[key] = df_transposed['features'].apply(lambda x: x.get(key))

# колонку 'features' удалим за дальнейшей ненадобностью
df_transposed.drop('features', axis=1, inplace=True)

# посмотрим что получилось
df_transposed.head()
# Out:
#   user_id  target exchange-sessions  \
# 0  user_1  female              None
# 1  user_2  female              None
# 2  user_3    male              None
# 3  user_4    male              None
# 4  user_5  female              None
#
#                                               orders  \
# 0  [{'site-id': 1, 'orders': [{'created-at': 1634...
# 1                                               None
# 2  [{'site-id': 21, 'orders': [{'created-at': 168...
# 3  [{'site-id': 2, 'orders': [{'created-at': 1600...
# 4  [{'site-id': 39, 'orders': [{'created-at': 164...
#
#                                               visits  \
# 0                                               None
# 1  [{'site-id': 3, 'first-seen': 1696277805, 'las...
# 2  [{'site-id': 3, 'first-seen': 1696320204, 'las...
# 3  [{'site-id': 3, 'first-seen': 1693468067, 'las...
# 4  [{'site-id': 3, 'first-seen': 1693796766, 'las...
#
#                                            site-meta  \
# 0                                   [{'site-id': 2}]
# 1  [{'site-id': 4}, {'site-id': 5}, {'site-id': 6...
# 2  [{'site-id': 24}, {'site-id': 25}, {'site-id':...
# 3  [{'site-id': 33}, {'site-id': 2}, {'site-id': ...
# 4  [{'site-id': 42}, {'site-id': 43}, {'site-id':...
#
#                            last-visits-in-categories
# 0                                               None
# 1  [{'category': 'other', 'last-visit-at': 169627...
# 2  [{'category': 'electronics', 'last-visit-at': ...
# 3  [{'category': 'hypermarket', 'last-visit-at': ...
# 4  [{'category': 'insurance', 'last-visit-at': 16...

# %%
# Функция рассчитывает определенные айди сайтов в колонке заказы
def count_site_ids_in_orders_modified(orders):
    site_id_counter = Counter()
    if orders is not None:
        for order_dict in orders:
            if 'orders' in order_dict and 'site-id' in order_dict:
                site_id = order_dict['site-id']
                for order in order_dict['orders']:
                    site_id_counter[site_id] += 1
    return site_id_counter

# %%
# Создадим новую колонку в которой будет количество заказов на каждом сайте для каждого пользователя
df_transposed['orders_count'] = df_transposed['orders'].apply(count_site_ids_in_orders_modified)

# посмотрим что получилось
df_transposed[['user_id', 'orders_count']].head()
# Out:
#   user_id                 orders_count
# 0  user_1                 {1: 1, 2: 2}
# 1  user_2                           {}
# 2  user_3               {21: 1, 22: 1}
# 3  user_4  {2: 1, 29: 2, 30: 4, 21: 1}
# 4  user_5        {39: 1, 40: 1, 20: 1}

# %%
# теперь тоже самое сделаем и для колонки с посещениями - посмотрим куда человек ходит и как часто
def count_site_ids_in_visits_modified(visits):
    site_id_counter = Counter()
    if visits is not None:
        for visit_group in visits:
            if 'visits' in visit_group and 'site-id' in visit_group:
                site_id = visit_group['site-id']
                for visit in visit_group['visits']:
                    site_id_counter[site_id] += 1
    return site_id_counter

# %%
# Применим функцию и создадим новый столбец
df_transposed['visits_count'] = df_transposed['visits'].apply(count_site_ids_in_visits_modified)

# посмотрим что получилось
df_transposed[['user_id', 'visits_count']].head()
# Out:
#   user_id                               visits_count
# 0  user_1                                         {}
# 1  user_2                                     {3: 2}
# 2  user_3                      {3: 1, 23: 3, 16: 10}
# 3  user_4  {3: 2, 21: 1, 20: 4, 31: 1, 30: 6, 32: 3}
# 4  user_5        {3: 3, 23: 1, 13: 7, 41: 2, 20: 10}

# %%
# теперь для каждого пользвателя мы хотим вытащить последние категории посещений
def extract_categories(last_visits):
    if last_visits is not None:
        return [visit['category'] for visit in last_visits]
    return []

# %%
# применим функцию и создадим новый столбец с требуемым списком
df_transposed['last_visited_categories'] = df_transposed['last-visits-in-categories'].apply(extract_categories)

# %%
# Checking the result for the first few users
df_transposed[['user_id', 'last_visited_categories']].head()
# Out:
#   user_id                            last_visited_categories
# 0  user_1                                                 []
# 1  user_2                                            [other]
# 2  user_3                               [electronics, other]
# 3  user_4                    [hypermarket, other, education]
# 4  user_5  [insurance, fashion, other, bank, pets, electr...

# %%
# посмотрим на на результат нашего features engeneering
df_transposed[['user_id', 'orders_count', 'visits_count', 'last_visited_categories']].head()
# Out:
#   user_id                 orders_count  \
# 0  user_1                 {1: 1, 2: 2}
# 1  user_2                           {}
# 2  user_3               {21: 1, 22: 1}
# 3  user_4  {2: 1, 29: 2, 30: 4, 21: 1}
# 4  user_5        {39: 1, 40: 1, 20: 1}
#
#                                 visits_count  \
# 0                                         {}
# 1                                     {3: 2}
# 2                      {3: 1, 23: 3, 16: 10}
# 3  {3: 2, 21: 1, 20: 4, 31: 1, 30: 6, 32: 3}
# 4        {3: 3, 23: 1, 13: 7, 41: 2, 20: 10}
#
#                              last_visited_categories
# 0                                                 []
# 1                                            [other]
# 2                               [electronics, other]
# 3                    [hypermarket, other, education]
# 4  [insurance, fashion, other, bank, pets, electr...

# %%
# Инициализация словарей для подсчета мужественности/женственности сайтов и категорий
site_stats_simplified = {}
category_stats = {}

# %%
# Коэффициент для учета важности заказов (думаю если заказ важнее посещения - то мы можем накрутить этот множитель)
k = 1

# %%
# Проход по каждой строке DataFrame с целью вытащить количество посещений кажого сайта и покупки 
for _, row in df_transposed.iterrows():
    gender = row['target']
    
    # Обработка orders_count
    for site_id, count in row['orders_count'].items():
        if site_id not in site_stats_simplified:
            site_stats_simplified[site_id] = {'male': 0, 'female': 0}
        site_stats_simplified[site_id][gender] += count * k

    # Обработка visits_count
    for site_id, count in row['visits_count'].items():
        if site_id not in site_stats_simplified:
            site_stats_simplified[site_id] = {'male': 0, 'female': 0}
        site_stats_simplified[site_id][gender] += count

    # Обработка last_visited_categories
    for category in row['last_visited_categories']:
        if category not in category_stats:
            category_stats[category] = {'male': 0, 'female': 0}
        category_stats[category][gender] += 1

# Теперь у нас есть словарь site_stats_simplified и category_stats с подробной статистикой по каждому сайту категорией

# %%
category_stats
# Out:
# {'other': {'male': 62416, 'female': 63176},
#  'electronics': {'male': 35223, 'female': 30532},
#  1434: {'male': 1, 'female': 1},
#  1248: {'male': 1, 'female': 1},
#  1787: {'male': 0, 'female': 1},
#  1788: {'male': 10, 'female': 0},
#  1567: {'male': 0, 'female': 2},
#  1190: {'male': 1, 'female': 0},
#  1584: {'male': 5, 'female': 1},
#  1533: {'male': 0, 'female': 2},
#  1791: {'male': 0, 'female': 2},
#  1502: {'male': 1, 'female': 1},
#  804: {'male': 1, 'female': 1},
#  1627: {'male': 0, 'female': 1},
#  329: {'male': 1, 'female': 0},
#  1053: {'male': 0, 'female': 21},
#  1674: {'male': 0, 'female': 1},
#  1642: {'male': 0, 'female': 1},
#  1793: {'male': 2, 'female': 0},
#  1702: {'male': 2, 'female': 1},
#  1695: {'male': 0, 'female': 4},
#  1435: {'male': 0, 'female': 3},
#  1492: {'male': 0, 'female': 1},
#  1723: {'male': 0, 'female': 1},
#  598: {'male': 1, 'female': 1},
#  1517: {'male': 0, 'female': 2},
#  742: {'male': 1, 'female': 0},
#  385: {'male': 1, 'female': 0},
#  1474: {'male': 0, 'female': 1},
#  1713: {'male': 0, 'female': 1},
#  ...}

# %%
# Словари для определения преобладающего пола
gender_dominant_sites = {site_id: 'female' if stats['female'] >= stats['male'] else 'male'
                         for site_id, stats in site_stats_simplified.items()}
gender_dominant_categories = {category: 'female' if stats['female'] >= stats['male'] else 'male'
                              for category, stats in category_stats.items()}

# %% [markdown]
# !!! вот эти словари я еще не пробовал для прогноза, надо будет тоже попробовать - может чем проще тем лучше

# %%
# Словари для расчета доли мужского и женского участия
gender_ratio_sites = {}
for site_id, stats in site_stats_simplified.items():
    total = stats['male'] + stats['female']
    if total > 0:
        gender_ratio_sites[site_id] = {'male': round(stats['male'] / total, 2), 'female': round(stats['female'] / total, 2)}

gender_ratio_categories = {}
for category, stats in category_stats.items():
    total = stats['male'] + stats['female']
    if total > 0:
        gender_ratio_categories[category] = {'male': round(stats['male'] / total, 2), 'female': round(stats['female'] / total, 2)}

# %%
# Результаты
gender_dominant_sites
# Out:
# {1: 'male',
#  2: 'male',
#  3: 'female',
#  21: 'male',
#  22: 'male',
#  23: 'male',
#  16: 'male',
#  29: 'male',
#  30: 'male',
#  20: 'male',
#  31: 'female',
#  32: 'female',
#  39: 'male',
#  40: 'male',
#  13: 'female',
#  41: 'male',
#  123: 'female',
#  50: 'female',
#  150: 'female',
#  146: 'female',
#  151: 'male',
#  205: 'female',
#  206: 'male',
#  63: 'female',
#  207: 'male',
#  208: 'female',
#  209: 'female',
#  225: 'female',
#  247: 'female',
#  35: 'male',
#  155: 'male',
#  147: 'male',
#  263: 'female',
#  10: 'female',
#  241: 'male',
#  196: 'female',
#  62: 'female',
#  307: 'female',
#  236: 'female',
#  175: 'female',
#  46: 'female',
#  246: 'female',
#  348: 'male',
#  12: 'female',
#  65: 'female',
#  49: 'female',
#  171: 'female',
#  129: 'female',
#  477: 'female',
#  389: 'male',
#  191: 'female',
#  320: 'female',
#  217: 'male',
#  478: 'male',
#  149: 'female',
#  160: 'male',
#  179: 'female',
#  25: 'male',
#  74: 'male',
#  325: 'female',
#  71: 'female',
#  58: 'female',
#  158: 'female',
#  34: 'female',
#  351: 'female',
#  26: 'male',
#  112: 'male',
#  98: 'female',
#  110: 'male',
#  118: 'female',
#  144: 'female',
#  37: 'male',
#  199: 'female',
#  51: 'female',
#  8: 'female',
#  371: 'female',
#  83: 'female',
#  103: 'female',
#  90: 'female',
#  79: 'male',
#  391: 'female',
#  117: 'female',
#  159: 'female',
#  96: 'female',
#  18: 'female',
#  7: 'female',
#  613: 'female',
#  266: 'female',
#  81: 'female',
#  194: 'female',
#  136: 'female',
#  42: 'female',
#  495: 'male',
#  132: 'female',
#  356: 'male',
#  485: 'female',
#  357: 'female',
#  218: 'female',
#  278: 'female',
#  552: 'female',
#  234: 'female',
#  614: 'male',
#  615: 'male',
#  501: 'male',
#  93: 'female',
#  616: 'female',
#  617: 'male',
#  606: 'female',
#  64: 'female',
#  618: 'female',
#  11: 'female',
#  111: 'female',
#  444: 'female',
#  323: 'female',
#  489: 'male',
#  555: 'male',
#  675: 'male',
#  135: 'female',
#  359: 'male',
#  164: 'male',
#  85: 'female',
#  399: 'female',
#  28: 'male',
#  317: 'female',
#  676: 'male',
#  558: 'male',
#  78: 'male',
#  441: 'male',
#  678: 'female',
#  173: 'female',
#  349: 'male',
#  346: 'male',
#  439: 'female',
#  203: 'female',
#  488: 'male',
#  100: 'female',
#  54: 'female',
#  174: 'female',
#  181: 'female',
#  153: 'male',
#  119: 'female',
#  86: 'female',
#  48: 'male',
#  24: 'male',
#  319: 'female',
#  651: 'female',
#  89: 'female',
#  130: 'female',
#  6: 'female',
#  694: 'male',
#  599: 'male',
#  256: 'male',
#  216: 'male',
#  104: 'female',
#  291: 'female',
#  709: 'female',
#  394: 'male',
#  537: 'female',
#  668: 'male',
#  711: 'female',
#  312: 'female',
#  287: 'female',
#  409: 'female',
#  581: 'male',
#  713: 'male',
#  124: 'male',
#  714: 'male',
#  114: 'female',
#  692: 'female',
#  715: 'female',
#  43: 'female',
#  396: 'female',
#  214: 'male',
#  33: 'male',
#  220: 'female',
#  578: 'male',
#  397: 'female',
#  134: 'female',
#  484: 'female',
#  451: 'female',
#  333: 'female',
#  108: 'female',
#  195: 'female',
#  107: 'female',
#  45: 'female',
#  192: 'male',
#  53: 'female',
#  725: 'male',
#  57: 'female',
#  97: 'female',
#  343: 'male',
#  162: 'female',
#  297: 'male',
#  44: 'female',
#  105: 'female',
#  341: 'female',
#  184: 'female',
#  9: 'male',
#  84: 'female',
#  80: 'female',
#  324: 'female',
#  373: 'male',
#  180: 'female',
#  19: 'male',
#  347: 'male',
#  167: 'male',
#  56: 'male',
#  646: 'female',
#  201: 'male',
#  311: 'male',
#  76: 'female',
#  355: 'male',
#  161: 'male',
#  166: 'male',
#  197: 'female',
#  193: 'male',
#  387: 'female',
#  272: 'female',
#  27: 'female',
#  361: 'female',
#  483: 'female',
#  61: 'female',
#  141: 'female',
#  536: 'female',
#  235: 'female',
#  755: 'female',
#  248: 'female',
#  183: 'female',
#  120: 'male',
#  756: 'female',
#  262: 'male',
#  198: 'male',
#  109: 'male',
#  758: 'female',
#  647: 'female',
#  770: 'female',
#  406: 'male',
#  771: 'female',
#  590: 'female',
#  303: 'male',
#  772: 'male',
#  658: 'female',
#  716: 'male',
#  407: 'female',
#  163: 'female',
#  276: 'male',
#  497: 'male',
#  301: 'male',
#  91: 'male',
#  778: 'male',
#  122: 'female',
#  719: 'female',
#  106: 'female',
#  264: 'female',
#  631: 'male',
#  779: 'female',
#  710: 'female',
#  275: 'female',
#  299: 'female',
#  94: 'female',
#  380: 'male',
#  365: 'male',
#  260: 'male',
#  585: 'male',
#  728: 'female',
#  190: 'female',
#  787: 'male',
#  340: 'female',
#  425: 'female',
#  684: 'female',
#  775: 'male',
#  657: 'female',
#  82: 'female',
#  685: 'female',
#  5: 'female',
#  99: 'female',
#  55: 'female',
#  490: 'female',
#  553: 'female',
#  812: 'male',
#  350: 'female',
#  633: 'female',
#  95: 'female',
#  69: 'female',
#  353: 'female',
#  498: 'female',
#  178: 'female',
#  807: 'female',
#  828: 'female',
#  59: 'female',
#  565: 'female',
#  316: 'male',
#  410: 'female',
#  826: 'female',
#  273: 'male',
#  334: 'female',
#  254: 'male',
#  223: 'male',
#  838: 'male',
#  226: 'female',
#  14: 'female',
#  139: 'male',
#  182: 'female',
#  645: 'female',
#  547: 'female',
#  330: 'male',
#  66: 'male',
#  474: 'female',
#  665: 'male',
#  168: 'male',
#  760: 'female',
#  148: 'male',
#  344: 'female',
#  421: 'female',
#  776: 'male',
#  445: 'female',
#  650: 'female',
#  750: 'male',
#  752: 'female',
#  849: 'male',
#  850: 'male',
#  699: 'male',
#  688: 'female',
#  283: 'male',
#  831: 'male',
#  689: 'female',
#  854: 'female',
#  187: 'male',
#  143: 'female',
#  200: 'female',
#  342: 'male',
#  352: 'male',
#  855: 'male',
#  102: 'male',
#  857: 'female',
#  418: 'female',
#  859: 'female',
#  612: 'female',
#  186: 'female',
#  369: 'male',
#  632: 'female',
#  863: 'male',
#  244: 'male',
#  556: 'male',
#  165: 'male',
#  433: 'female',
#  308: 'female',
#  137: 'female',
#  310: 'female',
#  687: 'female',
#  177: 'male',
#  327: 'female',
#  908: 'female',
#  172: 'female',
#  305: 'female',
#  376: 'male',
#  121: 'male',
#  393: 'male',
#  644: 'female',
#  127: 'female',
#  727: 'female',
#  935: 'female',
#  245: 'female',
#  313: 'female',
#  415: 'male',
#  372: 'female',
#  769: 'female',
#  535: 'male',
#  140: 'male',
#  115: 'female',
#  239: 'female',
#  285: 'female',
#  545: 'female',
#  321: 'female',
#  845: 'female',
#  601: 'female',
#  994: 'female',
#  627: 'female',
#  507: 'female',
#  734: 'female',
#  15: 'male',
#  683: 'male',
#  909: 'female',
#  653: 'female',
#  288: 'male',
#  737: 'male',
#  1006: 'female',
#  337: 'female',
#  116: 'male',
#  326: 'female',
#  830: 'male',
#  698: 'female',
#  877: 'female',
#  156: 'female',
#  251: 'female',
#  270: 'male',
#  210: 'male',
#  60: 'female',
#  560: 'female',
#  706: 'female',
#  360: 'male',
#  546: 'female',
#  1045: 'male',
#  338: 'female',
#  440: 'female',
#  629: 'female',
#  745: 'female',
#  1046: 'male',
#  222: 'female',
#  138: 'female',
#  1048: 'female',
#  77: 'female',
#  87: 'female',
#  429: 'male',
#  176: 'female',
#  290: 'female',
#  101: 'female',
#  691: 'male',
#  726: 'female',
#  257: 'female',
#  840: 'male',
#  882: 'female',
#  92: 'female',
#  822: 'male',
#  390: 'female',
#  1164: 'female',
#  805: 'male',
#  328: 'female',
#  744: 'male',
#  655: 'female',
#  392: 'male',
#  564: 'male',
#  404: 'female',
#  912: 'female',
#  972: 'female',
#  1172: 'female',
#  411: 'female',
#  448: 'female',
#  185: 'female',
#  586: 'female',
#  1163: 'male',
#  446: 'female',
#  315: 'female',
#  860: 'female',
#  259: 'female',
#  515: 'female',
#  568: 'female',
#  154: 'male',
#  934: 'female',
#  422: 'female',
#  835: 'female',
#  1182: 'female',
#  1057: 'male',
#  588: 'female',
#  739: 'male',
#  815: 'male',
#  374: 'male',
#  268: 'male',
#  602: 'female',
#  252: 'female',
#  718: 'female',
#  853: 'female',
#  735: 'male',
#  1225: 'male',
#  436: 'female',
#  788: 'female',
#  561: 'female',
#  669: 'female',
#  1015: 'male',
#  1232: 'female',
#  652: 'male',
#  654: 'female',
#  375: 'female',
#  431: 'female',
#  358: 'female',
#  293: 'female',
#  998: 'female',
#  589: 'female',
#  1238: 'male',
#  395: 'female',
#  871: 'female',
#  1005: 'female',
#  1243: 'male',
#  1244: 'female',
#  1050: 'female',
#  314: 'female',
#  496: 'female',
#  827: 'female',
#  1187: 'female',
#  300: 'female',
#  304: 'female',
#  377: 'female',
#  623: 'female',
#  891: 'female',
#  759: 'female',
#  1251: 'male',
#  68: 'male',
#  708: 'female',
#  1255: 'female',
#  666: 'female',
#  817: 'female',
#  243: 'female',
#  557: 'female',
#  240: 'female',
#  1264: 'female',
#  298: 'female',
#  1265: 'female',
#  1230: 'female',
#  721: 'female',
#  113: 'female',
#  1191: 'female',
#  242: 'male',
#  763: 'female',
#  202: 'female',
#  582: 'male',
#  292: 'female',
#  965: 'male',
#  751: 'female',
#  1266: 'male',
#  52: 'female',
#  1256: 'male',
#  258: 'male',
#  1276: 'female',
#  720: 'female',
#  931: 'female',
#  656: 'female',
#  73: 'female',
#  824: 'female',
#  766: 'female',
#  1177: 'female',
#  648: 'female',
#  1193: 'male',
#  221: 'female',
#  605: 'female',
#  690: 'female',
#  1293: 'female',
#  345: 'female',
#  1231: 'male',
#  749: 'female',
#  447: 'female',
#  1297: 'female',
#  872: 'male',
#  1298: 'female',
#  309: 'female',
#  1233: 'male',
#  157: 'female',
#  1301: 'male',
#  188: 'female',
#  332: 'female',
#  1155: 'female',
#  938: 'male',
#  1302: 'male',
#  832: 'female',
#  152: 'female',
#  630: 'female',
#  619: 'female',
#  1258: 'male',
#  978: 'female',
#  844: 'male',
#  1271: 'female',
#  1067: 'female',
#  482: 'female',
#  1220: 'female',
#  1310: 'female',
#  595: 'female',
#  936: 'female',
#  335: 'female',
#  843: 'female',
#  1324: 'female',
#  426: 'female',
#  821: 'female',
#  834: 'female',
#  836: 'female',
#  1325: 'male',
#  1328: 'female',
#  873: 'male',
#  438: 'female',
#  1329: 'female',
#  851: 'male',
#  1332: 'male',
#  800: 'female',
#  413: 'female',
#  480: 'female',
#  465: 'female',
#  1181: 'female',
#  204: 'male',
#  874: 'male',
#  712: 'female',
#  879: 'male',
#  876: 'male',
#  1339: 'male',
#  1340: 'male',
#  1341: 'male',
#  875: 'female',
#  423: 'female',
#  88: 'female',
#  249: 'female',
#  1347: 'male',
#  253: 'male',
#  820: 'female',
#  1176: 'female',
#  548: 'female',
#  604: 'female',
#  1241: 'female',
#  762: 'female',
#  322: 'female',
#  1354: 'female',
#  1014: 'female',
#  1356: 'male',
#  1065: 'female',
#  1178: 'female',
#  281: 'male',
#  789: 'female',
#  1345: 'female',
#  846: 'female',
#  1068: 'female',
#  1236: 'male',
#  1327: 'female',
#  476: 'female',
#  573: 'female',
#  883: 'female',
#  512: 'female',
#  277: 'male',
#  274: 'male',
#  1016: 'female',
#  1363: 'female',
#  649: 'female',
#  1018: 'female',
#  802: 'male',
#  717: 'female',
#  1249: 'female',
#  761: 'female',
#  1348: 'female',
#  995: 'female',
#  1188: 'female',
#  1370: 'female',
#  707: 'female',
#  932: 'female',
#  1371: 'female',
#  1158: 'female',
#  230: 'female',
#  1375: 'male',
#  1376: 'male',
#  75: 'male',
#  940: 'male',
#  1224: 'female',
#  417: 'male',
#  1011: 'female',
#  1306: 'female',
#  1185: 'female',
#  1267: 'male',
#  1004: 'female',
#  1268: 'female',
#  1382: 'female',
#  968: 'male',
#  1064: 'female',
#  1384: 'male',
#  1385: 'male',
#  128: 'male',
#  1261: 'female',
#  145: 'male',
#  1392: 'male',
#  1393: 'female',
#  1189: 'female',
#  681: 'male',
#  1252: 'female',
#  782: 'female',
#  1001: 'female',
#  494: 'female',
#  829: 'female',
#  624: 'female',
#  1364: 'male',
#  808: 'female',
#  1274: 'female',
#  1239: 'male',
#  841: 'female',
#  1407: 'female',
#  878: 'female',
#  861: 'female',
#  1273: 'male',
#  1281: 'female',
#  799: 'female',
#  1415: 'female',
#  1157: 'female',
#  757: 'male',
#  1409: 'male',
#  1413: 'female',
#  1380: 'female',
#  383: 'male',
#  1433: 'male',
#  428: 'female',
#  1056: 'female',
#  1436: 'female',
#  1387: 'female',
#  1292: 'male',
#  1438: 'female',
#  1291: 'female',
#  1441: 'female',
#  1429: 'female',
#  1440: 'female',
#  227: 'female',
#  970: 'female',
#  1333: 'female',
#  1466: 'male',
#  575: 'male',
#  1280: 'female',
#  1167: 'male',
#  1334: 'female',
#  1374: 'male',
#  1472: 'male',
#  1473: 'male',
#  231: 'male',
#  673: 'female',
#  563: 'female',
#  1002: 'female',
#  768: 'female',
#  833: 'male',
#  1277: 'male',
#  1319: 'male',
#  1489: 'female',
#  1312: 'male',
#  996: 'male',
#  1494: 'female',
#  1175: 'male',
#  1423: 'male',
#  572: 'female',
#  1338: 'female',
#  1051: 'female',
#  1500: 'female',
#  1283: 'male',
#  378: 'female',
#  1437: 'male',
#  596: 'female',
#  1290: 'female',
#  1307: 'female',
#  781: 'female',
#  705: 'male',
#  1254: 'female',
#  1534: 'female',
#  1259: 'female',
#  1535: 'female',
#  1179: 'female',
#  977: 'female',
#  1272: 'male',
#  1367: 'female',
#  1563: 'male',
#  1566: 'female',
#  1184: 'female',
#  1570: 'male',
#  847: 'female',
#  1381: 'female',
#  1285: 'female',
#  1486: 'female',
#  1063: 'male',
#  930: 'female',
#  189: 'male',
#  1320: 'male',
#  1257: 'female',
#  848: 'male',
#  1477: 'female',
#  508: 'female',
#  1396: 'female',
#  1403: 'male',
#  816: 'female',
#  339: 'male',
#  1390: 'female',
#  1410: 'female',
#  976: 'female',
#  1349: 'male',
#  1481: 'female',
#  1471: 'male',
#  505: 'male',
#  570: 'female',
#  686: 'male',
#  1352: 'female',
#  170: 'female',
#  1289: 'female',
#  1597: 'male',
#  1590: 'female',
#  864: 'male',
#  743: 'female',
#  1237: 'male',
#  780: 'male',
#  1600: 'female',
#  1311: 'female',
#  1183: 'female',
#  1010: 'female',
#  1240: 'male',
#  1362: 'female',
#  408: 'female',
#  1000: 'male',
#  362: 'male',
#  1606: 'female',
#  1322: 'male',
#  1424: 'female',
#  746: 'male',
#  754: 'female',
#  1596: 'female',
#  1616: 'female',
#  773: 'female',
#  1536: 'female',
#  1247: 'female',
#  1618: 'female',
#  1620: 'female',
#  910: 'female',
#  1342: 'female',
#  1162: 'male',
#  1245: 'female',
#  806: 'female',
#  1613: 'male',
#  1625: 'male',
#  510: 'male',
#  142: 'male',
#  1270: 'female',
#  1304: 'female',
#  1305: 'female',
#  1361: 'male',
#  1628: 'female',
#  1485: 'female',
#  1478: 'female',
#  1166: 'female',
#  1343: 'female',
#  1335: 'female',
#  765: 'female',
#  1624: 'female',
#  1395: 'male',
#  1637: 'female',
#  1269: 'male',
#  1017: 'female',
#  1425: 'male',
#  1639: 'male',
#  1480: 'female',
#  1055: 'female',
#  1355: 'male',
#  1156: 'male',
#  1442: 'female',
#  937: 'female',
#  1052: 'female',
#  1351: 'male',
#  798: 'female',
#  1408: 'male',
#  1591: 'male',
#  1496: 'male',
#  388: 'female',
#  1465: 'male',
#  1648: 'male',
#  1428: 'female',
#  1406: 'female',
#  506: 'female',
#  1641: 'male',
#  1610: 'female',
#  1659: 'male',
#  1501: 'male',
#  1368: 'female',
#  255: 'male',
#  569: 'female',
#  767: 'female',
#  1250: 'female',
#  1373: 'female',
#  1560: 'male',
#  554: 'female',
#  1336: 'female',
#  1402: 'female',
#  738: 'female',
#  1615: 'male',
#  1479: 'female',
#  1608: 'female',
#  1505: 'female',
#  1482: 'female',
#  1587: 'female',
#  1282: 'female',
#  1602: 'male',
#  1603: 'male',
#  1515: 'male',
#  1386: 'male',
#  819: 'male',
#  1604: 'male',
#  1601: 'male',
#  1503: 'female',
#  1049: 'female',
#  1445: 'female',
#  1467: 'female',
#  1504: 'male',
#  671: 'female',
#  1583: 'female',
#  1468: 'female',
#  842: 'male',
#  1507: 'male',
#  1419: 'male',
#  1372: 'male',
#  1516: 'male',
#  1676: 'male',
#  1532: 'male',
#  1426: 'male',
#  1522: 'male',
#  1677: 'female',
#  1681: 'female',
#  1174: 'female',
#  1422: 'female',
#  1671: 'female',
#  1317: 'male',
#  1344: 'female',
#  724: 'female',
#  1686: 'male',
#  539: 'female',
#  703: 'female',
#  1487: 'female',
#  1672: 'female',
#  969: 'female',
#  1499: 'female',
#  1694: 'male',
#  1278: 'male',
#  1493: 'female',
#  1330: 'female',
#  1594: 'female',
#  1629: 'female',
#  1682: 'male',
#  1475: 'female',
#  1565: 'female',
#  1701: 'female',
#  1173: 'male',
#  1235: 'female',
#  1295: 'female',
#  1655: 'male',
#  1470: 'male',
#  1711: 'male',
#  1712: 'female',
#  1353: 'female',
#  1675: 'female',
#  1537: 'female',
#  1716: 'female',
#  1670: 'female',
#  1668: 'female',
#  1490: 'male',
#  1595: 'female',
#  1564: 'female',
#  1263: 'male',
#  1491: 'female',
#  1359: 'female',
#  1573: 'female',
#  1383: 'male',
#  1652: 'female',
#  1696: 'female',
#  453: 'female',
#  449: 'female',
#  1299: 'female',
#  1357: 'female',
#  1495: 'female',
#  783: 'female',
#  467: 'female',
#  1242: 'female',
#  1647: 'female',
#  1718: 'male',
#  1727: 'female',
#  1397: 'male',
#  1599: 'male',
#  1667: 'male',
#  818: 'male',
#  1007: 'female',
#  1684: 'female',
#  1394: 'female',
#  1735: 'female',
#  1683: 'female',
#  1360: 'male',
#  1294: 'male',
#  1704: 'female',
#  1673: 'female',
#  1366: 'male',
#  1605: 'male',
#  1785: 'female',
#  1412: 'female',
#  1253: 'female',
#  1434: 'female',
#  1248: 'female',
#  1787: 'female',
#  1788: 'male',
#  1567: 'female',
#  1190: 'male',
#  1584: 'male',
#  1533: 'female',
#  1791: 'female',
#  1502: 'female',
#  804: 'female',
#  1627: 'female',
#  329: 'male',
#  1053: 'female',
#  1674: 'female',
#  1642: 'female',
#  1793: 'male',
#  1702: 'male',
#  1695: 'female',
#  1435: 'female',
#  1492: 'female',
#  1723: 'female',
#  598: 'female',
#  1517: 'female',
#  742: 'male',
#  385: 'male',
#  1474: 'female',
#  1713: 'female',
#  ...}

# %%
gender_dominant_categories
# Out:
# {'other': 'female',
#  'electronics': 'male',
#  'hypermarket': 'male',
#  'education': 'female',
#  'insurance': 'male',
#  'fashion': 'female',
#  'bank': 'male',
#  'pets': 'female',
#  'cosmetics': 'female',
#  'entertainment_services': 'female',
#  'health': 'female',
#  'media': 'male',
#  'furniture': 'female',
#  'shoes': 'female',
#  'travel': 'female',
#  'household_appliances': 'male',
#  'food': 'female',
#  'kids': 'female',
#  'luxury': 'female',
#  'gifts': 'female',
#  'dealoftheday': 'female',
#  'sport': 'female',
#  'software': 'male',
#  '"0" => "f", "1" => "a", "2" => "s", "3" => "h", "4" => "i", "5" => "o", "6" => "n"': 'female'}

# %%
gender_ratio_sites
# Out:
#  1674: {'male': 0.0, 'female': 1.0},
#  1642: {'male': 0.0, 'female': 1.0},
#  1793: {'male': 1.0, 'female': 0.0},
#  1702: {'male': 0.67, 'female': 0.33},
#  1695: {'male': 0.0, 'female': 1.0},
#  1435: {'male': 0.0, 'female': 1.0},
#  1492: {'male': 0.0, 'female': 1.0},
#  1723: {'male': 0.0, 'female': 1.0},
#  598: {'male': 0.5, 'female': 0.5},
#  1517: {'male': 0.0, 'female': 1.0},
#  742: {'male': 1.0, 'female': 0.0},
#  385: {'male': 1.0, 'female': 0.0},
#  1474: {'male': 0.0, 'female': 1.0},
#  1713: {'male': 0.0, 'female': 1.0},
#  ...}

# %%
gender_ratio_categories
# Out:
# {'other': {'male': 0.5, 'female': 0.5},
#  'electronics': {'male': 0.54, 'female': 0.46},
#  'hypermarket': {'male': 0.52, 'female': 0.48},
#  'education': {'male': 0.45, 'female': 0.55},
#  'insurance': {'male': 0.55, 'female': 0.45},
#  'fashion': {'male': 0.41, 'female': 0.59},
#  'bank': {'male': 0.56, 'female': 0.44},
#  'pets': {'male': 0.33, 'female': 0.67},
#  'cosmetics': {'male': 0.34, 'female': 0.66},
#  'entertainment_services': {'male': 0.45, 'female': 0.55},
#  'health': {'male': 0.38, 'female': 0.62},
#  'media': {'male': 0.5, 'female': 0.5},
#  'furniture': {'male': 0.42, 'female': 0.58},
#  'shoes': {'male': 0.36, 'female': 0.64},
#  'travel': {'male': 0.43, 'female': 0.57},
#  'household_appliances': {'male': 0.58, 'female': 0.42},
#  'food': {'male': 0.47, 'female': 0.53},
#  'kids': {'male': 0.34, 'female': 0.66},
#  'luxury': {'male': 0.41, 'female': 0.59},
#  'gifts': {'male': 0.35, 'female': 0.65},
#  'dealoftheday': {'male': 0.43, 'female': 0.57},
#  'sport': {'male': 0.43, 'female': 0.57},
#  'software': {'male': 0.66, 'female': 0.34},
#  '"0" => "f", "1" => "a", "2" => "s", "3" => "h", "4" => "i", "5" => "o", "6" => "n"': {'male': 0.0,
#   'female': 1.0}}

# %% [markdown]
# В целом на первый взгляд есть в этих правилах вполне понятная логика

# %% [markdown]
# ## Приступаем к работе над валидационным набором данных

# %%
df_val = pd.read_json('val.json')

# %% [markdown]
# Тут просто копировал ячейки и менял название датафрейма, описание можно потом поменять ну и вообще обернуть это все в функции

# %%
# транспонируем датасет что бы он принял человеческий вид
df_transposed_val = df_val.T

# зададим имена колонок (важно когда будем работать с тестовым набором то колонки таргет у нас не будет)
df_transposed_val.reset_index(inplace=True)
df_transposed_val.rename(columns={'index': 'user_id', 0: 'target', 1: 'features'}, inplace=True)

# Посмотрим что получилось
df_transposed_val.head()
# Out:
#        user_id  target                                           features
# 0  user_127756  female  {'orders': [{'site-id': 407, 'orders': [{'crea...
# 1  user_127757    male  {'orders': [{'site-id': 16, 'orders': [{'creat...
# 2  user_127758  female  {'orders': [{'site-id': 149, 'orders': [{'crea...
# 3  user_127759  female  {'orders': [{'site-id': 93, 'orders': [{'creat...
# 4  user_127760  female  {'visits': [{'site-id': 3, 'first-seen': 16836...

# %%
# найдем все унникальные ключи внути ключа features
unique_keys = set()
for features in df_transposed_val['features']:
    unique_keys.update(features.keys())

# создадим из них новые колонки извлекая данные из 'features'
for key in unique_keys:
    df_transposed_val[key] = df_transposed_val['features'].apply(lambda x: x.get(key))

# колонку 'features' удалим за дальнейшей ненадобностью
df_transposed_val.drop('features', axis=1, inplace=True)

# посмотрим что получилось
df_transposed_val.head()
# Out:
#        user_id  target                                  exchange-sessions  \
# 0  user_127756  female  [{'landed-at': 1697132982, 'sites': [169, 214,...
# 1  user_127757    male  [{'landed-at': 1693508972, 'sites': [2, 169, 7...
# 2  user_127758  female                                               None
# 3  user_127759  female  [{'landed-at': 1697791749, 'sites': [373, 169,...
# 4  user_127760  female                                               None
#
#                                               orders  \
# 0  [{'site-id': 407, 'orders': [{'created-at': 16...
# 1  [{'site-id': 16, 'orders': [{'created-at': 163...
# 2  [{'site-id': 149, 'orders': [{'created-at': 16...
# 3  [{'site-id': 93, 'orders': [{'created-at': 162...
# 4                                               None
#
#                                               visits  \
# 0  [{'site-id': 3, 'first-seen': 1697125590, 'las...
# 1  [{'site-id': 3, 'first-seen': 1698423484, 'las...
# 2  [{'site-id': 391, 'first-seen': 1685615371, 'l...
# 3  [{'site-id': 495, 'first-seen': 1687325784, 'l...
# 4  [{'site-id': 3, 'first-seen': 1683626530, 'las...
#
#                                            site-meta  \
# 0                                 [{'site-id': 407}]
# 1  [{'site-id': 16, 'recency': 1, 'frequency': 5,...
# 2  [{'site-id': 391}, {'site-id': 42}, {'site-id'...
# 3  [{'site-id': 93, 'recency': 5, 'frequency': 2,...
# 4  [{'site-id': 46}, {'site-id': 29}, {'site-id':...
#
#                            last-visits-in-categories
# 0  [{'category': 'other', 'last-visit-at': 169713...
# 1  [{'category': 'electronics', 'last-visit-at': ...
# 2  [{'category': 'sport', 'last-visit-at': 165060...
# 3  [{'category': 'furniture', 'last-visit-at': 16...
# 4  [{'category': 'other', 'last-visit-at': 169765...

# %%
# Создадим новую колонку в которой будет количество заказов на каждом сайте для каждого пользователя
df_transposed_val['orders_count'] = df_transposed_val['orders'].apply(count_site_ids_in_orders_modified)

# посмотрим что получилось
df_transposed_val[['user_id', 'orders_count']].head()
# Out:
#        user_id                            orders_count
# 0  user_127756                                {407: 1}
# 1  user_127757          {16: 10, 40: 1, 288: 1, 21: 2}
# 2  user_127758  {149: 2, 25: 1, 21: 2, 100: 1, 474: 1}
# 3  user_127759                 {93: 8, 134: 1, 103: 1}
# 4  user_127760                                      {}

# %%
# Применим функцию и создадим новый столбец
df_transposed_val['visits_count'] = df_transposed_val['visits'].apply(count_site_ids_in_visits_modified)

# посмотрим что получилось
df_transposed_val[['user_id', 'visits_count']].head()
# Out:
#        user_id                                       visits_count
# 0  user_127756                                    {3: 2, 407: 10}
# 1  user_127757                              {3: 1, 308: 1, 16: 1}
# 2  user_127758  {391: 1, 42: 7, 485: 1, 820: 1, 97: 5, 39: 1, ...
# 3  user_127759  {495: 1, 34: 9, 484: 1, 334: 1, 205: 1, 31: 1,...
# 4  user_127760                                      {3: 2, 34: 1}

# %%
# применим функцию и создадим новый столбец с требуемым списком
df_transposed_val['last_visited_categories'] = df_transposed_val['last-visits-in-categories'].apply(extract_categories)
# Checking the result for the first few users
df_transposed_val[['user_id', 'last_visited_categories']].head()
# Out:
#        user_id                            last_visited_categories
# 0  user_127756                                 [other, education]
# 1  user_127757                        [electronics, other, shoes]
# 2  user_127758  [sport, furniture, fashion, other, bank, house...
# 3  user_127759  [furniture, fashion, other, food, electronics,...
# 4  user_127760                                 [other, cosmetics]

# %%
# посмотрим на на результат нашего features engeneering
df_transposed_val[['user_id', 'orders_count', 'visits_count', 'last_visited_categories']].head()
# Out:
#        user_id                            orders_count  \
# 0  user_127756                                {407: 1}
# 1  user_127757          {16: 10, 40: 1, 288: 1, 21: 2}
# 2  user_127758  {149: 2, 25: 1, 21: 2, 100: 1, 474: 1}
# 3  user_127759                 {93: 8, 134: 1, 103: 1}
# 4  user_127760                                      {}
#
#                                         visits_count  \
# 0                                    {3: 2, 407: 10}
# 1                              {3: 1, 308: 1, 16: 1}
# 2  {391: 1, 42: 7, 485: 1, 820: 1, 97: 5, 39: 1, ...
# 3  {495: 1, 34: 9, 484: 1, 334: 1, 205: 1, 31: 1,...
# 4                                      {3: 2, 34: 1}
#
#                              last_visited_categories
# 0                                 [other, education]
# 1                        [electronics, other, shoes]
# 2  [sport, furniture, fashion, other, bank, house...
# 3  [furniture, fashion, other, food, electronics,...
# 4                                 [other, cosmetics]

# %% [markdown]
# # Переходим к предсказаниям

# %% [markdown]
# Вот с этой функцией можно поиграть что то отключить,  а может и что то добавить.

# %%
# Создание столбца predict_gender
def predict_gender(row):
    male_score = 0
    female_score = 0

    # Подсчет для orders
    for site_id, count in row['orders_count'].items():
        if site_id in gender_ratio_sites:
            male_score += gender_ratio_sites[site_id]['male'] * count
            female_score += gender_ratio_sites[site_id]['female'] * count

    # Подсчет для visits
    for site_id, count in row['visits_count'].items():
        if site_id in gender_ratio_sites:
            male_score += gender_ratio_sites[site_id]['male'] * count
            female_score += gender_ratio_sites[site_id]['female'] * count

    # Подсчет для categories
    for category in row['last_visited_categories']:
        if category in gender_ratio_categories:
            male_score += gender_ratio_categories[category]['male']
            female_score += gender_ratio_categories[category]['female']

    return 'female' if female_score >= male_score else 'male'

# %%
# Применение функции к DataFrame
df_transposed_val['predict_gender'] = df_transposed_val.apply(predict_gender, axis=1)

# %%
# Результаты
df_transposed_val[['user_id', 'target','predict_gender']]
# Out:
#            user_id  target predict_gender
# 0      user_127756  female         female
# 1      user_127757    male           male
# 2      user_127758  female         female
# 3      user_127759  female         female
# 4      user_127760  female         female
# ...            ...     ...            ...
# 27442  user_155198  female         female
# 27443  user_155199    male         female
# 27444  user_155200  female         female
# 27445  user_155201    male         female
# 27446  user_155202  female         female
#
# [27447 rows x 3 columns]

# %% [markdown]
# Нужно будет внимательно посмотреть на пользователей по которым мы ошиблись

# %%
def calculate_accuracy(df):
    correct_predictions = df[df['target'] == df['predict_gender']].shape[0]
    total_predictions = df.shape[0]
    accuracy = correct_predictions / total_predictions
    return accuracy

# %%
# Вызов функции для расчета accuracy
accuracy = calculate_accuracy(df_transposed_val)
accuracy
# Out:
# 0.7164717455459613

# %% [markdown]
# # Анализ ошибок

# %%
# Создание DataFrame с ошибочными предсказаниями
df_errors = df_transposed_val[df_transposed_val['target'] != df_transposed_val['predict_gender']]

# %%
# Вывод первых нескольких строк DataFrame с ошибочными предсказаниями
df_errors.head()
# Out:
#         user_id  target                                  exchange-sessions  \
# 8   user_127764    male                                               None
# 9   user_127765  female                                               None
# 14  user_127770  female                                               None
# 15  user_127771    male  [{'landed-at': 1698678911, 'sites': [169, 2, 2...
# 20  user_127776    male  [{'landed-at': 1697833017, 'sites': [2, 169, 7...
#
#                                                orders  \
# 8   [{'site-id': 179, 'orders': [{'created-at': 13...
# 9   [{'site-id': 16, 'orders': [{'created-at': 156...
# 14  [{'site-id': 39, 'orders': [{'created-at': 167...
# 15  [{'site-id': 62, 'orders': [{'created-at': 168...
# 20  [{'site-id': 49, 'orders': [{'created-at': 150...
#
#                                                visits  \
# 8   [{'site-id': 3, 'first-seen': 1690804257, 'las...
# 9   [{'site-id': 3, 'first-seen': 1684519666, 'las...
# 14  [{'site-id': 13, 'first-seen': 1684836326, 'la...
# 15  [{'site-id': 34, 'first-seen': 1685510491, 'la...
# 20  [{'site-id': 912, 'first-seen': 1688017479, 'l...
#
#                                             site-meta  \
# 8   [{'site-id': 179, 'recency': 1, 'frequency': 2...
# 9   [{'site-id': 2}, {'site-id': 16, 'recency': 1,...
# 14  [{'site-id': 2}, {'site-id': 39, 'recency': 1,...
# 15  [{'site-id': 42}, {'site-id': 33}, {'site-id':...
# 20  [{'site-id': 495}, {'site-id': 49, 'recency': ...
#
#                             last-visits-in-categories  \
# 8   [{'category': 'fashion', 'last-visit-at': 1685...
# 9   [{'category': 'other', 'last-visit-at': 169651...
# 14  [{'category': 'bank', 'last-visit-at': 1674136...
# 15  [{'category': 'fashion', 'last-visit-at': 1698...
# 20  [{'category': 'other', 'last-visit-at': 169783...
#
#                                          orders_count  \
# 8                                     {179: 2, 40: 1}
# 9                               {16: 1, 2: 6, 691: 2}
# 14                              {39: 1, 244: 1, 1: 1}
# 15               {62: 1, 40: 1, 209: 2, 29: 5, 74: 1}
# 20  {49: 10, 191: 1, 34: 1, 112: 6, 21: 1, 39: 1, ...
#
#                                          visits_count  \
# 8    {3: 2, 13: 1, 2: 1, 208: 2, 85: 2, 431: 6, 7: 1}
# 9                                              {3: 4}
# 14                                      {13: 1, 3: 1}
# 15  {34: 2, 135: 2, 149: 1, 26: 4, 110: 2, 713: 1,...
# 20  {912: 2, 495: 5, 66: 1, 178: 1, 357: 1, 51: 1,...
#
#                               last_visited_categories predict_gender
# 8   [fashion, other, bank, household_appliances, f...         female
# 9                                             [other]           male
# 14  [bank, electronics, other, media, cosmetics, f...           male
# 15  [fashion, other, bank, electronics, cosmetics,...         female
# 20  [other, bank, travel, pets, food, electronics,...         female
