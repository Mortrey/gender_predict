# %%
import json

# %%
import pprint

# %%
# Load the JSON files
file_path_cut = 'cut.json'

# %%
# Re-attempting to load the JSON file as a JSON object
with open(file_path_cut, 'r', encoding='utf-8') as file:
    json_data = json.load(file)

# %%
type_of_json_data = type(json_data)
print(type_of_json_data)
# Out:
# <class 'dict'>

# %%
json_keys = list(json_data.keys())
json_keys[2]
# Out:
# 'user_127758'

# %%
# Checking the keys and structure of the JSON object

first_key_structure = json_data[json_keys[0]] if len(json_keys) > 0 else "No keys"

first_key_structure
# Out:
# {'target': 'female',
#  'features': {'orders': [{'site-id': 407,
#     'orders': [{'created-at': 1697125567,
#       'items': [{'id': 'item_676374', 'count': None}]}]}],
#   'visits': [{'site-id': 3,
#     'first-seen': 1697125590,
#     'last-seen': 1697132982,
#     'visits': [{'visited-at': 1697125590,
#       'session-duration': 0,
#       'pages-count': 1},
#      {'visited-at': 1697132982, 'session-duration': 0, 'pages-count': 1}]},
#    {'site-id': 407,
#     'first-seen': 1697124789,
#     'last-seen': 1699114961,
#     'visits': [{'visited-at': 1698854716,
#       'session-duration': 626,
#       'pages-count': 3},
#      {'visited-at': 1698931220, 'session-duration': 0, 'pages-count': 1},
#      {'visited-at': 1698947134, 'session-duration': 0, 'pages-count': 1},
#      {'visited-at': 1698951468, 'session-duration': 392, 'pages-count': 2},
#      {'visited-at': 1698953769, 'session-duration': 0, 'pages-count': 1},
# ...

# %%
# вот тут удобно смотреть структуру
formatted_json = json.dumps(json_data[json_keys[2]], indent=2)
print(formatted_json)
# Out:
# {
#   "target": "female",
#   "features": {
#     "orders": [
#       {
#         "site-id": 149,
#         "orders": [
#           {
#             "created-at": 1658740897,
#             "items": [
#               {
#                 "id": "item_3868047",
#                 "count": null,
#                 "general-category-path": [
#                   13243353,
#                   91182,
#                   91157,
#                   90509
#                 ],
#                 "brand-id": 1844
#               },
#               {
#                 "id": "item_43151",
#                 "count": null,
#                 "general-category-path": [
#                   7693914,
#                   91172,
#                   90509
#                 ],
#                 "brand-id": 4690
#               },
#               {
#                 "id": "item_2265109",
#                 "count": null,
#                 "general-category-path": [
#                   91174,
# ...

# %%
# Pretty printing the JSON structure for better readability
pretty_json = json.dumps(first_key_structure, indent=4)

pretty_json
# Out:
# '{\n    "target": "female",\n    "features": {\n        "orders": [\n            {\n                "site-id": 407,\n                "orders": [\n                    {\n                        "created-at": 1697125567,\n                        "items": [\n                            {\n                                "id": "item_676374",\n                                "count": null\n                            }\n                        ]\n                    }\n                ]\n            }\n        ],\n        "visits": [\n            {\n                "site-id": 3,\n                "first-seen": 1697125590,\n                "last-seen": 1697132982,\n                "visits": [\n                    {\n                        "visited-at": 1697125590,\n                        "session-duration": 0,\n                        "pages-count": 1\n                    },\n                    {\n                        "visited-at": 1697132982,\n                        "session-duratio
# ...

# %%
json_data['user_127778']
# Out:
# {'target': 'male',
#  'features': {'orders': [{'site-id': 37,
#     'orders': [{'created-at': 1599220350, 'items': []}]},
#    {'site-id': 34,
#     'orders': [{'created-at': 1605015583,
#       'items': [{'id': 'item_826168', 'count': 1},
#        {'id': 'item_1781', 'count': 1}]}]},
#    {'site-id': 123,
#     'orders': [{'created-at': 1633504464,
#       'items': [{'id': 'item_5409431',
#         'count': 1,
#         'general-category-path': [7812157, 7811877, 7877999],
#         'brand-id': 2458}]},
#      {'created-at': 1635181237,
#       'items': [{'id': 'item_5409431',
#         'count': 1,
#         'general-category-path': [7812157, 7811877, 7877999],
#         'brand-id': 2458}]}]},
#    {'site-id': 46,
#     'orders': [{'created-at': 1688244856,
#       'items': [{'id': 'item_19120', 'count': 1}]},
#      {'created-at': 1688245777, 'items': [{'id': 'item_898806', 'count': 1}]},
#      {'created-at': 1688488221, 'items': [{'id': 'item_68173', 'count': 1}]}]},
# ...
